# %% [markdown]
# **Batch size doubled from 128 to 256**

# %%
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
batch_size = 256
num_classes = 10
epochs = 40

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
x_train = x_train.reshape(50000, 3072)
x_test = x_test.reshape(10000, 3072)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 50000 train samples
# 10000 test samples

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 14s 272us/step - loss: 2.4211 - acc: 0.2237 - val_loss: 1.9503 - val_acc: 0.2758
# Epoch 2/40
# 50000/50000 [==============================] - 14s 275us/step - loss: 1.9112 - acc: 0.3058 - val_loss: 1.9658 - val_acc: 0.2727
# Epoch 3/40
# 50000/50000 [==============================] - 13s 267us/step - loss: 1.8356 - acc: 0.3392 - val_loss: 1.7480 - val_acc: 0.3601
# Epoch 4/40
# 50000/50000 [==============================] - 14s 278us/step - loss: 1.7805 - acc: 0.3611 - val_loss: 1.7877 - val_acc: 0.3761
# Epoch 5/40
# 50000/50000 [==============================] - 14s 275us/step - loss: 1.7295 - acc: 0.3803 - val_loss: 1.7453 - val_acc: 0.3699
# Epoch 6/40
# 50000/50000 [==============================] - 14s 278us/step - loss: 1.6978 - acc: 0.3945 - val_loss: 1.6341 - val_acc: 0.4143
# Epoch 7/40
# 50000/50000 [==============================] - 14s 278us/step - loss: 1.6710 - acc: 0.4019 - val_loss: 1.8610 - val_acc: 0.3229
# Epoch 8/40
# 50000/50000 [==============================] - 14s 279us/step - loss: 1.6460 - acc: 0.4121 - val_loss: 1.6116 - val_acc: 0.4278
# Epoch 9/40
# 50000/50000 [==============================] - 14s 281us/step - loss: 1.6240 - acc: 0.4211 - val_loss: 1.6111 - val_acc: 0.4185
# Epoch 10/40
# 50000/50000 [==============================] - 14s 280us/step - loss: 1.6092 - acc: 0.4267 - val_loss: 1.6868 - val_acc: 0.3930
# Epoch 11/40
# 50000/50000 [==============================] - 14s 286us/step - loss: 1.5887 - acc: 0.4317 - val_loss: 1.6111 - val_acc: 0.4247
# Epoch 12/40
# 50000/50000 [==============================] - 14s 281us/step - loss: 1.5815 - acc: 0.4349 - val_loss: 1.6860 - val_acc: 0.4018
# Epoch 13/40
# 50000/50000 [==============================] - 14s 280us/step - loss: 1.5631 - acc: 0.4411 - val_loss: 1.5950 - val_acc: 0.4345
# Epoch 14/40
# 50000/50000 [==============================] - 14s 274us/step - loss: 1.5522 - acc: 0.4440 - val_loss: 1.6300 - val_acc: 0.4106
# Epoch 15/40
# 50000/50000 [==============================] - 14s 273us/step - loss: 1.5390 - acc: 0.4490 - val_loss: 1.5485 - val_acc: 0.4578
# Epoch 16/40
# 50000/50000 [==============================] - 14s 274us/step - loss: 1.5272 - acc: 0.4516 - val_loss: 1.5061 - val_acc: 0.4680
# Epoch 17/40
# 50000/50000 [==============================] - 14s 273us/step - loss: 1.5164 - acc: 0.4552 - val_loss: 1.5141 - val_acc: 0.4690
# Epoch 18/40
# 50000/50000 [==============================] - 14s 276us/step - loss: 1.5104 - acc: 0.4597 - val_loss: 1.5269 - val_acc: 0.4630
# Epoch 19/40
# 50000/50000 [==============================] - 14s 273us/step - loss: 1.5014 - acc: 0.4622 - val_loss: 1.4853 - val_acc: 0.4745
# Epoch 20/40
# 50000/50000 [==============================] - 14s 273us/step - loss: 1.4976 - acc: 0.4656 - val_loss: 1.5521 - val_acc: 0.4380
# Epoch 21/40
# 50000/50000 [==============================] - 14s 274us/step - loss: 1.4811 - acc: 0.4708 - val_loss: 1.5304 - val_acc: 0.4692
# Epoch 22/40
# 50000/50000 [==============================] - 14s 274us/step - loss: 1.4766 - acc: 0.4734 - val_loss: 1.5646 - val_acc: 0.4439
# Epoch 23/40
# 50000/50000 [==============================] - 14s 272us/step - loss: 1.4708 - acc: 0.4739 - val_loss: 1.5018 - val_acc: 0.4793
# Epoch 24/40
# 50000/50000 [==============================] - 14s 274us/step - loss: 1.4647 - acc: 0.4770 - val_loss: 1.4588 - val_acc: 0.4822
# Epoch 25/40
# 50000/50000 [==============================] - 14s 272us/step - loss: 1.4567 - acc: 0.4776 - val_loss: 1.5674 - val_acc: 0.4489
# Epoch 26/40
# 50000/50000 [==============================] - 14s 271us/step - loss: 1.4506 - acc: 0.4806 - val_loss: 1.5585 - val_acc: 0.4461
# Epoch 27/40
# 50000/50000 [==============================] - 14s 272us/step - loss: 1.4477 - acc: 0.4828 - val_loss: 1.4839 - val_acc: 0.4819
# Epoch 28/40
# 50000/50000 [==============================] - 14s 271us/step - loss: 1.4351 - acc: 0.4870 - val_loss: 1.5250 - val_acc: 0.4533
# Epoch 29/40
# 50000/50000 [==============================] - 14s 270us/step - loss: 1.4317 - acc: 0.4889 - val_loss: 1.5141 - val_acc: 0.4633
# Epoch 30/40
# 50000/50000 [==============================] - 14s 272us/step - loss: 1.4298 - acc: 0.4915 - val_loss: 1.4915 - val_acc: 0.4702
# Epoch 31/40
# 50000/50000 [==============================] - 14s 272us/step - loss: 1.4214 - acc: 0.4913 - val_loss: 1.6149 - val_acc: 0.4241
# Epoch 32/40
# 50000/50000 [==============================] - 14s 272us/step - loss: 1.4194 - acc: 0.4947 - val_loss: 1.4889 - val_acc: 0.4706
# Epoch 33/40
# 50000/50000 [==============================] - 14s 273us/step - loss: 1.4086 - acc: 0.4960 - val_loss: 1.4823 - val_acc: 0.4708
# Epoch 34/40
# 50000/50000 [==============================] - 14s 277us/step - loss: 1.4101 - acc: 0.4975 - val_loss: 1.4851 - val_acc: 0.4651
# Epoch 35/40
# 50000/50000 [==============================] - 14s 273us/step - loss: 1.4065 - acc: 0.5001 - val_loss: 1.4495 - val_acc: 0.4852
# Epoch 36/40
# 50000/50000 [==============================] - 14s 274us/step - loss: 1.3994 - acc: 0.4983 - val_loss: 1.4577 - val_acc: 0.4778
# Epoch 37/40
# 50000/50000 [==============================] - 14s 274us/step - loss: 1.3946 - acc: 0.5015 - val_loss: 1.5098 - val_acc: 0.4682
# Epoch 38/40
# 50000/50000 [==============================] - 14s 274us/step - loss: 1.3869 - acc: 0.5038 - val_loss: 1.4856 - val_acc: 0.4735
# Epoch 39/40
# 50000/50000 [==============================] - 14s 274us/step - loss: 1.3831 - acc: 0.5053 - val_loss: 1.5144 - val_acc: 0.4692
# Epoch 40/40
# 50000/50000 [==============================] - 14s 274us/step - loss: 1.3764 - acc: 0.5085 - val_loss: 1.4521 - val_acc: 0.4770
# Test loss: 1.4521178142547608
# Test accuracy: 0.477

# %%
plt.figure(0)
plt.plot(history.history['acc'],'r')
plt.plot(history.history['val_acc'],'g')
plt.xticks(np.arange(0, 40, 2.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Accuracy")
plt.title("Training Accuracy vs Validation Accuracy")
plt.legend(['train','validation'])
plt.show()

# %%
plt.figure(1)
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'g')
plt.xticks(np.arange(0, 40, 4.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation'])
plt.show()

# %% [markdown]
# **Conclusion:**
# Doubled the batch size from 128 to 256. The model is overfitting. But the running time reduced by 6 secs per Epoch.
