# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel('CNN_Model.xlsx')

# %%
df.head()
# Out:
#    Training Accuracy  Testing Accuracy  Loss  Val Loss  Epochs Activation   \
# 0              64.03             67.25  1.02      0.94      20        relu
# 1              71.37             72.08  0.80      0.74      40        relu
# 2              75.82             78.46  0.69      0.63      35        relu
# 3              79.25             79.80  0.59      0.60      60        relu
# 4              72.55             74.54  0.79      0.75      40        relu
#
#   Optimizer  Batch_size Convolution_Layers  ANN_Layers      ...        \
# 0   RMSprop          32                  1           1      ...
# 1      Adam          32                  1           1      ...
# 2    Adamax          64                  4           2      ...
# 3    Adamax          64                  4           2      ...
# 4    Adamax         128                  6           1      ...
#
#    ANN_layer2  ANN_layer3  CNN_layer1  CNN_layer2  CNN_layer3  CNN_layer4  \
# ...

# %%
# summarize history for accuracy
plt.plot(df['Training Accuracy'])
plt.plot(df['Testing Accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(df['Loss'])
plt.plot(df['Val Loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
sns.pairplot(data=df[['Training Accuracy','Testing Accuracy']])

# %%
sns.pairplot(data=df[['Loss','Val Loss']])

# %%
colors = {'RMSprop': 'r', 'Adam': 'b', 'Adamax': 'g'}
df['Testing Accuracy'].plot(kind='bar', color=[colors[i] for i in df['Optimizer']])
plt.ylabel('Test Accuracy')
plt.xlabel('Optimizers')
plt.legend(labels=('RMSprop','Adam','Adamax'), loc='upper left',prop={'size': 10})
plt.rcParams['figure.figsize'] = (8, 6)
plt.show()
